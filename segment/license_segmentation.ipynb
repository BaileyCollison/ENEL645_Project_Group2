# %%
### IMPORTS ###
import os
import xml.etree.ElementTree as ET
from PIL import Image
import shutil
import random
from ultralytics import YOLO
import cv2

# %%
## INSTRUCTIONS:
# Download dataset from: https://www.kaggle.com/datasets/andrewmvd/car-plate-detection
# unzip and rename to 'car-license-plate-detection' then add to 'segment' directory 
# Run this cell

annotation_folder = "car-license-plate-detection/annotations"
output_folder = "car-license-plate-detection/yolo_annotations" 
os.makedirs(output_folder, exist_ok=True)

# Only one class in this dataset
class_map = {'licence':0}

# %%
# Annotations are in PASCAL VOC format.
# Need to convert to YOLO format
    """ Parses xml annotations and converts them to YOLO format
    """

def convert_annotation(xml_file, output_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Image dimensions from <size> tag
    size = root.find('size')
    width = int(size.find('width').text)
    height = int(size.find('height').text)

    with open(output_file, 'w') as out_file:
        for obj in root.iter('object'):
            label = obj.find('name').text.lower()
            
            # This should be unecessary, but safety first :)
            if label not in class_map:
                continue
            
            # YOLO needs class id
            class_id = class_map[label]

            # Get bbox coords
            xmlbox = obj.find('bndbox')
            xmin = float(xmlbox.find('xmin').text)
            ymin = float(xmlbox.find('ymin').text)
            xmax = float(xmlbox.find('xmax').text)
            ymax = float(xmlbox.find('ymax').text)

            # YOLO requires normalized values (x,y,w,h)
            x_center = ((xmin + xmax) / 2) / width
            y_center = ((ymin + ymax) / 2) / height
            w = (xmax - xmin) / width
            h = (ymax - ymin) / height

            # Write new file in YOLO format
            out_file.write(f"{class_id} {x_center} {y_center} {w} {h}\n")

for xml_file in os.listdir(annotation_folder):
    if xml_file.endswith('.xml'):
        xml_path = os.path.join(annotation_folder, xml_file)
        #Cars0.xml -> Cars0.txt
        output_file = os.path.join(output_folder, os.path.splitext(xml_file)[0] + '.txt')
        convert_annotation(xml_path, output_file)

print("Finished converting. Output directory:", output_folder)
# Out:
# Finished converting. Output directory: car-license-plate-detection/yolo_annotations

# %%
# Need to split dataset

# Base directories 
base_images_dir = 'car-license-plate-detection/images'
base_xml_dir = 'car-license-plate-detection/annotations'         
base_yolo_dir = 'car-license-plate-detection/yolo_annotations'     

# New Directories 
train_images_dir = 'car-license-plate-detection/train/images'
val_images_dir   = 'car-license-plate-detection/val/images'
test_images_dir  = 'car-license-plate-detection/test/images'

# Ultralytics expects /labels directory
train_yolo_dir   = 'car-license-plate-detection/train/labels'
val_yolo_dir     = 'car-license-plate-detection/val/labels'
test_yolo_dir    = 'car-license-plate-detection/test/labels'

train_xml_dir    = 'car-license-plate-detection/train/xml_annotations'
val_xml_dir      = 'car-license-plate-detection/val/xml_annotations'  
test_xml_dir     = 'car-license-plate-detection/test/xml_annotations' 

# Create destination directories
dest_dirs = [train_images_dir, val_images_dir, test_images_dir,
             train_yolo_dir, val_yolo_dir, test_yolo_dir,
             train_xml_dir, val_xml_dir, test_xml_dir]
for d in dest_dirs:
    os.makedirs(d, exist_ok=True)

# List all image files 
image_files = [f for f in os.listdir(base_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
random.shuffle(image_files)

#(70% train, 15% validation, 15% test)
n_total = len(image_files)
n_train = int(0.70 * n_total)
n_val   = int(0.15 * n_total)
n_test  = n_total - n_train - n_val 

train_files = image_files[:n_train]
val_files   = image_files[n_train:n_train+n_val]
test_files  = image_files[n_train+n_val:]

def copy_files(file_list, src_img_dir, src_yolo_dir, src_xml_dir, dst_img_dir, dst_yolo_dir, dst_xml_dir):
    for file in file_list:
        # Copy image file
        shutil.copy(os.path.join(src_img_dir, file), os.path.join(dst_img_dir, file))
        
        # YOLO ANNOTATIONS
        yolo_file = os.path.splitext(file)[0] + '.txt'
        src_yolo_file = os.path.join(src_yolo_dir, yolo_file)
        if os.path.exists(src_yolo_file):
            shutil.copy(src_yolo_file, os.path.join(dst_yolo_dir, yolo_file))
        
        # XML ANNOTATIONS
        xml_file = os.path.splitext(file)[0] + '.xml'
        src_xml_file = os.path.join(src_xml_dir, xml_file)
        if os.path.exists(src_xml_file):
            shutil.copy(src_xml_file, os.path.join(dst_xml_dir, xml_file))

# Training files
copy_files(train_files, base_images_dir, base_yolo_dir, base_xml_dir, 
           train_images_dir, train_yolo_dir, train_xml_dir)

# Validation files
copy_files(val_files, base_images_dir, base_yolo_dir, base_xml_dir, 
           val_images_dir, val_yolo_dir, val_xml_dir)

# Test Files
copy_files(test_files, base_images_dir, base_yolo_dir, base_xml_dir, 
           test_images_dir, test_yolo_dir, test_xml_dir)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='data.yaml',
    epochs=20,
    batch=16,
    imgsz=640 # Yolo assumes 640
)

# %%
###
# This code takes license plate photos then uses our model to crop images to just the licesnse plate
# and save the cropped images.
###

# Change after training
model = YOLO('runs/detect/train7/weights/best.pt')

input_dir = 'car-license-plate-detection/images'
output_dir = 'cropped_images'

os.makedirs(output_dir, exist_ok=True)

for image in os.listdir(input_dir):
    if image.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_dir, image)
        
        # Inference
        results = model(image_path)
        result = results[0]
        img = result.orig_img
        
        for idx, bbox in enumerate(result.boxes.xyxy):
            x1, y1, x2, y2 = map(int, bbox)
            
            cropped_img = img[y1:y2, x1:x2]
            
            org_name = os.path.splitext(image)[0]
            new_name = f"{org_name}_cropped.png"
            output_path = os.path.join(output_dir, new_name)
            
            cv2.imwrite(output_path, cropped_img)
            
# Compress output folder
shutil.make_archive('cropped_images', 'zip', output_dir)
# Out:
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars207.png: 640x544 1 license_plate, 141.7ms
# Speed: 3.2ms preprocess, 141.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars213.png: 480x640 1 license_plate, 160.7ms
# Speed: 1.4ms preprocess, 160.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars53.png: 480x640 1 license_plate, 108.9ms
# Speed: 1.1ms preprocess, 108.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars47.png: 480x640 2 license_plates, 115.7ms
# Speed: 3.1ms preprocess, 115.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars90.png: 480x640 1 license_plate, 107.5ms
# Speed: 1.3ms preprocess, 107.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars159.png: 544x640 1 license_plate, 167.3ms
# Speed: 1.5ms preprocess, 167.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars84.png: 480x640 1 license_plate, 107.9ms
# Speed: 1.8ms preprocess, 107.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars171.png: 448x640 1 license_plate, 146.1ms
# Speed: 1.1ms preprocess, 146.1ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars165.png: 384x640 1 license_plate, 138.0ms
# Speed: 1.0ms preprocess, 138.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars398.png: 480x640 1 license_plate, 108.3ms
# Speed: 1.1ms preprocess, 108.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars429.png: 640x512 1 license_plate, 164.7ms
# Speed: 1.8ms preprocess, 164.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars373.png: 384x640 1 license_plate, 93.5ms
# Speed: 0.9ms preprocess, 93.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars415.png: 480x640 1 license_plate, 104.5ms
# Speed: 1.1ms preprocess, 104.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars401.png: 480x640 1 license_plate, 102.8ms
# Speed: 1.2ms preprocess, 102.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars367.png: 448x640 1 license_plate, 99.0ms
# Speed: 1.2ms preprocess, 99.0ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars400.png: 448x640 1 license_plate, 118.2ms
# Speed: 1.2ms preprocess, 118.2ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars366.png: 384x640 1 license_plate, 94.5ms
# Speed: 1.0ms preprocess, 94.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars372.png: 480x640 1 license_plate, 105.5ms
# Speed: 1.4ms preprocess, 105.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars414.png: 448x640 1 license_plate, 95.9ms
# Speed: 1.1ms preprocess, 95.9ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars428.png: 384x640 1 license_plate, 88.8ms
# Speed: 0.9ms preprocess, 88.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars399.png: 384x640 1 license_plate, 88.0ms
# Speed: 1.1ms preprocess, 88.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars164.png: 448x640 1 license_plate, 100.9ms
# Speed: 1.8ms preprocess, 100.9ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars170.png: 480x640 2 license_plates, 105.7ms
# Speed: 1.2ms preprocess, 105.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars85.png: 448x640 2 license_plates, 98.0ms
# Speed: 1.1ms preprocess, 98.0ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars158.png: 480x640 1 license_plate, 138.1ms
# Speed: 1.6ms preprocess, 138.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars91.png: 416x640 1 license_plate, 148.7ms
# Speed: 1.7ms preprocess, 148.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars46.png: 576x640 1 license_plate, 182.8ms
# Speed: 1.5ms preprocess, 182.8ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars52.png: 480x640 1 license_plate, 149.1ms
# Speed: 2.0ms preprocess, 149.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars212.png: 480x640 1 license_plate, 102.3ms
# Speed: 2.4ms preprocess, 102.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars206.png: 480x640 1 license_plate, 107.4ms
# Speed: 1.7ms preprocess, 107.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars238.png: 448x640 1 license_plate, 109.7ms
# Speed: 1.2ms preprocess, 109.7ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars210.png: 448x640 2 license_plates, 136.9ms
# Speed: 1.2ms preprocess, 136.9ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars204.png: 480x640 1 license_plate, 117.2ms
# Speed: 2.2ms preprocess, 117.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars199.png: 448x640 2 license_plates, 97.4ms
# Speed: 1.4ms preprocess, 97.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars44.png: 480x640 2 license_plates, 100.6ms
# Speed: 1.2ms preprocess, 100.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars50.png: 384x640 1 license_plate, 89.0ms
# Speed: 1.0ms preprocess, 89.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars78.png: 480x640 1 license_plate, 104.7ms
# Speed: 1.2ms preprocess, 104.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars87.png: 480x640 3 license_plates, 103.4ms
# Speed: 1.6ms preprocess, 103.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars93.png: 416x640 2 license_plates, 91.8ms
# Speed: 1.2ms preprocess, 91.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars166.png: 640x480 1 license_plate, 149.2ms
# Speed: 1.2ms preprocess, 149.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars172.png: 608x640 1 license_plate, 175.4ms
# Speed: 2.2ms preprocess, 175.4ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars358.png: 320x640 2 license_plates, 122.1ms
# Speed: 0.8ms preprocess, 122.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars364.png: 416x640 1 license_plate, 94.3ms
# Speed: 1.0ms preprocess, 94.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars402.png: 384x640 2 license_plates, 94.1ms
# Speed: 1.1ms preprocess, 94.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars416.png: 480x640 1 license_plate, 105.4ms
# Speed: 1.4ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars370.png: 448x640 1 license_plate, 99.5ms
# Speed: 1.1ms preprocess, 99.5ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars417.png: 480x640 1 license_plate, 103.4ms
# Speed: 1.2ms preprocess, 103.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars371.png: 320x640 1 license_plate, 74.8ms
# Speed: 1.0ms preprocess, 74.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars365.png: 448x640 1 license_plate, 96.9ms
# Speed: 1.2ms preprocess, 96.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars403.png: 512x640 2 license_plates, 155.4ms
# Speed: 1.4ms preprocess, 155.4ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars359.png: 480x640 1 license_plate, 137.7ms
# Speed: 1.4ms preprocess, 137.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars173.png: 384x640 1 license_plate, 88.6ms
# Speed: 1.1ms preprocess, 88.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars167.png: 512x640 1 license_plate, 109.0ms
# Speed: 1.8ms preprocess, 109.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars92.png: 448x640 1 license_plate, 98.8ms
# Speed: 1.2ms preprocess, 98.8ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars86.png: 384x640 1 license_plate, 87.7ms
# Speed: 1.0ms preprocess, 87.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars79.png: 576x640 1 license_plate, 119.3ms
# Speed: 2.0ms preprocess, 119.3ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars51.png: 448x640 1 license_plate, 98.3ms
# Speed: 1.4ms preprocess, 98.3ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars45.png: 416x640 1 license_plate, 90.7ms
# Speed: 1.3ms preprocess, 90.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars198.png: 512x640 1 license_plate, 111.0ms
# Speed: 1.5ms preprocess, 111.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars205.png: 640x640 1 license_plate, 183.0ms
# Speed: 2.4ms preprocess, 183.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars211.png: 480x640 1 license_plate, 115.2ms
# Speed: 1.1ms preprocess, 115.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars239.png: 512x640 1 license_plate, 105.3ms
# Speed: 1.2ms preprocess, 105.3ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars215.png: 384x640 5 license_plates, 88.0ms
# Speed: 1.9ms preprocess, 88.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars201.png: 384x640 1 license_plate, 85.8ms
# Speed: 1.3ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars229.png: 384x640 2 license_plates, 87.9ms
# Speed: 0.9ms preprocess, 87.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars69.png: 448x640 1 license_plate, 98.4ms
# Speed: 1.1ms preprocess, 98.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars41.png: 640x512 1 license_plate, 110.3ms
# Speed: 1.6ms preprocess, 110.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars55.png: 480x640 1 license_plate, 99.7ms
# Speed: 1.5ms preprocess, 99.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars188.png: 640x480 (no detections), 103.4ms
# Speed: 2.5ms preprocess, 103.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars163.png: 384x640 1 license_plate, 88.1ms
# Speed: 1.0ms preprocess, 88.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars177.png: 384x640 1 license_plate, 88.5ms
# Speed: 0.9ms preprocess, 88.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars82.png: 256x640 1 license_plate, 108.2ms
# Speed: 0.8ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars96.png: 416x640 1 license_plate, 90.8ms
# Speed: 1.0ms preprocess, 90.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars407.png: 448x640 1 license_plate, 106.4ms
# Speed: 1.2ms preprocess, 106.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars361.png: 480x640 1 license_plate, 104.5ms
# Speed: 1.3ms preprocess, 104.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars375.png: 480x640 1 license_plate, 102.6ms
# Speed: 1.3ms preprocess, 102.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars413.png: 416x640 2 license_plates, 91.4ms
# Speed: 1.0ms preprocess, 91.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars349.png: 448x640 1 license_plate, 96.3ms
# Speed: 1.3ms preprocess, 96.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars348.png: 384x640 1 license_plate, 89.0ms
# Speed: 1.0ms preprocess, 89.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars374.png: 352x640 1 license_plate, 145.9ms
# Speed: 1.0ms preprocess, 145.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars412.png: 384x640 1 license_plate, 89.2ms
# Speed: 1.0ms preprocess, 89.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars406.png: 448x640 1 license_plate, 97.7ms
# Speed: 1.2ms preprocess, 97.7ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars360.png: 384x640 1 license_plate, 90.4ms
# Speed: 0.9ms preprocess, 90.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars97.png: 480x640 1 license_plate, 104.7ms
# Speed: 1.1ms preprocess, 104.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars83.png: 480x640 1 license_plate, 106.5ms
# Speed: 2.4ms preprocess, 106.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars176.png: 416x640 2 license_plates, 94.7ms
# Speed: 1.1ms preprocess, 94.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars162.png: 384x640 (no detections), 94.7ms
# Speed: 1.2ms preprocess, 94.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars189.png: 448x640 1 license_plate, 102.3ms
# Speed: 1.4ms preprocess, 102.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars54.png: 480x640 1 license_plate, 122.0ms
# Speed: 1.5ms preprocess, 122.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars40.png: 384x640 1 license_plate, 193.0ms
# Speed: 0.9ms preprocess, 193.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars68.png: 448x640 1 license_plate, 121.4ms
# Speed: 1.2ms preprocess, 121.4ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars228.png: 320x640 2 license_plates, 82.3ms
# Speed: 1.2ms preprocess, 82.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars200.png: 416x640 1 license_plate, 94.3ms
# Speed: 1.2ms preprocess, 94.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars214.png: 416x640 2 license_plates, 89.1ms
# Speed: 1.0ms preprocess, 89.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars202.png: 480x640 1 license_plate, 103.0ms
# Speed: 1.1ms preprocess, 103.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars216.png: 512x640 1 license_plate, 110.8ms
# Speed: 1.3ms preprocess, 110.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars56.png: 320x640 1 license_plate, 156.3ms
# Speed: 0.8ms preprocess, 156.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars42.png: 384x640 1 license_plate, 93.2ms
# Speed: 1.0ms preprocess, 93.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars174.png: 384x640 3 license_plates, 90.7ms
# Speed: 0.9ms preprocess, 90.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars160.png: 384x640 1 license_plate, 86.3ms
# Speed: 1.0ms preprocess, 86.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars95.png: 448x640 1 license_plate, 94.4ms
# Speed: 1.2ms preprocess, 94.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars148.png: 384x640 1 license_plate, 88.5ms
# Speed: 0.9ms preprocess, 88.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars81.png: 480x640 2 license_plates, 99.4ms
# Speed: 1.2ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars389.png: 480x640 1 license_plate, 104.7ms
# Speed: 1.3ms preprocess, 104.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars410.png: 640x512 1 license_plate, 106.3ms
# Speed: 3.3ms preprocess, 106.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars376.png: 448x640 1 license_plate, 96.3ms
# Speed: 1.5ms preprocess, 96.3ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars362.png: 480x640 2 license_plates, 99.7ms
# Speed: 1.7ms preprocess, 99.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars404.png: 640x608 1 license_plate, 189.2ms
# Speed: 1.5ms preprocess, 189.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars363.png: 448x640 1 license_plate, 122.4ms
# Speed: 1.1ms preprocess, 122.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars405.png: 384x640 2 license_plates, 91.8ms
# Speed: 1.0ms preprocess, 91.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars411.png: 448x640 1 license_plate, 97.3ms
# Speed: 1.5ms preprocess, 97.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars377.png: 384x640 1 license_plate, 90.1ms
# Speed: 0.9ms preprocess, 90.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars388.png: 480x640 (no detections), 123.6ms
# Speed: 1.5ms preprocess, 123.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars80.png: 480x640 1 license_plate, 102.9ms
# Speed: 1.3ms preprocess, 102.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars149.png: 480x640 1 license_plate, 103.9ms
# Speed: 1.3ms preprocess, 103.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars94.png: 512x640 1 license_plate, 124.5ms
# Speed: 1.6ms preprocess, 124.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars161.png: 512x640 1 license_plate, 142.8ms
# Speed: 1.5ms preprocess, 142.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars175.png: 480x640 (no detections), 100.4ms
# Speed: 1.3ms preprocess, 100.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars43.png: 384x640 1 license_plate, 91.5ms
# Speed: 1.0ms preprocess, 91.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars57.png: 384x640 1 license_plate, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars217.png: 384x640 1 license_plate, 93.5ms
# Speed: 0.9ms preprocess, 93.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars203.png: 448x640 1 license_plate, 97.4ms
# Speed: 1.2ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars258.png: 448x640 1 license_plate, 99.1ms
# Speed: 1.2ms preprocess, 99.1ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars264.png: 640x640 1 license_plate, 133.6ms
# Speed: 1.5ms preprocess, 133.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars270.png: 384x640 2 license_plates, 86.0ms
# Speed: 0.9ms preprocess, 86.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars30.png: 384x640 2 license_plates, 88.9ms
# Speed: 1.1ms preprocess, 88.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars24.png: 480x640 1 license_plate, 105.8ms
# Speed: 1.3ms preprocess, 105.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars18.png: 512x640 1 license_plate, 108.2ms
# Speed: 1.2ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars112.png: 640x384 1 license_plate, 139.2ms
# Speed: 1.0ms preprocess, 139.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars106.png: 416x640 6 license_plates, 91.5ms
# Speed: 1.0ms preprocess, 91.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars3.png: 384x640 1 license_plate, 83.6ms
# Speed: 0.9ms preprocess, 83.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars338.png: 448x640 1 license_plate, 99.7ms
# Speed: 1.4ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars310.png: 576x640 1 license_plate, 121.7ms
# Speed: 1.5ms preprocess, 121.7ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars304.png: 384x640 1 license_plate, 91.3ms
# Speed: 1.0ms preprocess, 91.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars305.png: 384x640 2 license_plates, 86.7ms
# Speed: 1.0ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars311.png: 448x640 3 license_plates, 95.1ms
# Speed: 1.4ms preprocess, 95.1ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars339.png: 384x640 1 license_plate, 87.2ms
# Speed: 1.0ms preprocess, 87.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars2.png: 640x640 1 license_plate, 129.8ms
# Speed: 1.6ms preprocess, 129.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars107.png: 384x640 1 license_plate, 151.8ms
# Speed: 4.6ms preprocess, 151.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars113.png: 480x640 1 license_plate, 124.8ms
# Speed: 2.2ms preprocess, 124.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars19.png: 384x640 1 license_plate, 103.1ms
# Speed: 1.1ms preprocess, 103.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars25.png: 384x640 1 license_plate, 108.4ms
# Speed: 1.1ms preprocess, 108.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars31.png: 416x640 1 license_plate, 105.9ms
# Speed: 1.2ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars271.png: 448x640 1 license_plate, 99.4ms
# Speed: 1.2ms preprocess, 99.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars265.png: 352x640 1 license_plate, 80.0ms
# Speed: 0.9ms preprocess, 80.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars259.png: 384x640 1 license_plate, 87.7ms
# Speed: 1.0ms preprocess, 87.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars298.png: 448x640 1 license_plate, 194.2ms
# Speed: 1.6ms preprocess, 194.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars273.png: 384x640 1 license_plate, 112.7ms
# Speed: 1.1ms preprocess, 112.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars267.png: 352x640 2 license_plates, 86.1ms
# Speed: 1.8ms preprocess, 86.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars27.png: 384x640 1 license_plate, 91.2ms
# Speed: 1.0ms preprocess, 91.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars33.png: 384x640 1 license_plate, 102.0ms
# Speed: 1.4ms preprocess, 102.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars139.png: 480x640 3 license_plates, 100.1ms
# Speed: 1.8ms preprocess, 100.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars105.png: 384x640 2 license_plates, 89.6ms
# Speed: 0.9ms preprocess, 89.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars0.png: 352x640 1 license_plate, 85.9ms
# Speed: 1.1ms preprocess, 85.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars111.png: 384x640 1 license_plate, 109.2ms
# Speed: 1.3ms preprocess, 109.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars307.png: 448x640 1 license_plate, 96.2ms
# Speed: 1.3ms preprocess, 96.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars313.png: 512x640 1 license_plate, 117.7ms
# Speed: 1.2ms preprocess, 117.7ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars312.png: 384x640 1 license_plate, 89.1ms
# Speed: 1.2ms preprocess, 89.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars306.png: 640x640 1 license_plate, 129.4ms
# Speed: 1.5ms preprocess, 129.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars110.png: 448x640 1 license_plate, 105.9ms
# Speed: 1.1ms preprocess, 105.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars1.png: 416x640 1 license_plate, 95.8ms
# Speed: 1.4ms preprocess, 95.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars104.png: 480x640 1 license_plate, 98.6ms
# Speed: 1.2ms preprocess, 98.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars138.png: 512x640 (no detections), 121.6ms
# Speed: 1.2ms preprocess, 121.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars32.png: 480x640 1 license_plate, 110.5ms
# Speed: 1.1ms preprocess, 110.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars26.png: 384x640 1 license_plate, 138.4ms
# Speed: 1.2ms preprocess, 138.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars266.png: 384x640 5 license_plates, 97.7ms
# Speed: 7.4ms preprocess, 97.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars272.png: 288x640 1 license_plate, 120.6ms
# Speed: 0.8ms preprocess, 120.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars299.png: 480x640 1 license_plate, 114.2ms
# Speed: 1.1ms preprocess, 114.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars289.png: 512x640 1 license_plate, 107.3ms
# Speed: 1.6ms preprocess, 107.3ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars276.png: 448x640 1 license_plate, 97.4ms
# Speed: 2.0ms preprocess, 97.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars262.png: 512x640 1 license_plate, 108.8ms
# Speed: 1.5ms preprocess, 108.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars22.png: 480x640 1 license_plate, 103.5ms
# Speed: 1.3ms preprocess, 103.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars36.png: 480x640 1 license_plate, 99.3ms
# Speed: 1.3ms preprocess, 99.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars100.png: 448x640 1 license_plate, 98.2ms
# Speed: 1.1ms preprocess, 98.2ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars5.png: 480x640 (no detections), 101.8ms
# Speed: 1.2ms preprocess, 101.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars114.png: 384x640 1 license_plate, 86.1ms
# Speed: 1.0ms preprocess, 86.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars128.png: 384x640 1 license_plate, 85.1ms
# Speed: 1.2ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars302.png: 320x640 1 license_plate, 82.5ms
# Speed: 0.8ms preprocess, 82.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars316.png: 480x640 3 license_plates, 123.7ms
# Speed: 1.6ms preprocess, 123.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars317.png: 480x640 1 license_plate, 106.7ms
# Speed: 1.2ms preprocess, 106.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars303.png: 480x640 1 license_plate, 105.3ms
# ...
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars74.png: 448x640 1 license_plate, 98.4ms
# Speed: 1.2ms preprocess, 98.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars142.png: 320x640 1 license_plate, 77.9ms
# Speed: 0.8ms preprocess, 77.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars156.png: 320x640 1 license_plate, 79.2ms
# Speed: 0.8ms preprocess, 79.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars383.png: 448x640 1 license_plate, 100.7ms
# Speed: 1.2ms preprocess, 100.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars397.png: 480x640 1 license_plate, 113.8ms
# Speed: 1.4ms preprocess, 113.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars426.png: 480x640 2 license_plates, 102.6ms
# Speed: 1.2ms preprocess, 102.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars340.png: 320x640 1 license_plate, 75.6ms
# Speed: 0.8ms preprocess, 75.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars354.png: 448x640 1 license_plate, 96.3ms
# Speed: 1.1ms preprocess, 96.3ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars432.png: 416x640 1 license_plate, 95.6ms
# Speed: 1.3ms preprocess, 95.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars368.png: 480x640 1 license_plate, 103.6ms
# Speed: 2.2ms preprocess, 103.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars369.png: 512x640 1 license_plate, 109.4ms
# Speed: 1.3ms preprocess, 109.4ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars355.png: 448x640 1 license_plate, 94.7ms
# Speed: 1.1ms preprocess, 94.7ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars427.png: 480x640 1 license_plate, 120.1ms
# Speed: 1.3ms preprocess, 120.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars341.png: 448x640 1 license_plate, 117.7ms
# Speed: 1.9ms preprocess, 117.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars396.png: 640x480 1 license_plate, 104.4ms
# Speed: 1.3ms preprocess, 104.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars382.png: 480x640 2 license_plates, 101.4ms
# Speed: 1.3ms preprocess, 101.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars157.png: 448x640 1 license_plate, 96.1ms
# Speed: 1.2ms preprocess, 96.1ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars143.png: 448x640 2 license_plates, 134.7ms
# Speed: 1.1ms preprocess, 134.7ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars75.png: 416x640 (no detections), 96.4ms
# Speed: 1.4ms preprocess, 96.4ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars61.png: 480x640 1 license_plate, 110.7ms
# Speed: 1.2ms preprocess, 110.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars194.png: 448x640 1 license_plate, 101.8ms
# Speed: 1.3ms preprocess, 101.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars49.png: 416x640 1 license_plate, 123.4ms
# Speed: 1.0ms preprocess, 123.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars180.png: 480x640 1 license_plate, 120.7ms
# Speed: 1.9ms preprocess, 120.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars209.png: 480x640 1 license_plate, 104.4ms
# Speed: 1.3ms preprocess, 104.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars221.png: 384x640 1 license_plate, 91.4ms
# Speed: 0.9ms preprocess, 91.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars235.png: 384x640 1 license_plate, 85.6ms
# Speed: 0.9ms preprocess, 85.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars223.png: 448x640 4 license_plates, 96.5ms
# Speed: 1.2ms preprocess, 96.5ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars237.png: 640x512 1 license_plate, 114.7ms
# Speed: 1.1ms preprocess, 114.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars196.png: 416x640 1 license_plate, 107.2ms
# Speed: 1.1ms preprocess, 107.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars182.png: 384x640 1 license_plate, 88.4ms
# Speed: 0.9ms preprocess, 88.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars77.png: 448x640 1 license_plate, 101.0ms
# Speed: 1.1ms preprocess, 101.0ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars63.png: 448x640 1 license_plate, 103.3ms
# Speed: 1.1ms preprocess, 103.3ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars88.png: 480x640 1 license_plate, 113.3ms
# Speed: 2.3ms preprocess, 113.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars155.png: 448x640 1 license_plate, 100.4ms
# Speed: 1.2ms preprocess, 100.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars141.png: 448x640 2 license_plates, 96.4ms
# Speed: 1.1ms preprocess, 96.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars169.png: 320x640 1 license_plate, 76.3ms
# Speed: 0.8ms preprocess, 76.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars394.png: 480x640 1 license_plate, 102.0ms
# Speed: 1.2ms preprocess, 102.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars380.png: 384x640 1 license_plate, 87.2ms
# Speed: 0.9ms preprocess, 87.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars431.png: 320x640 1 license_plate, 80.6ms
# Speed: 0.8ms preprocess, 80.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars357.png: 448x640 2 license_plates, 97.5ms
# Speed: 1.9ms preprocess, 97.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars343.png: 480x640 1 license_plate, 98.8ms
# Speed: 1.4ms preprocess, 98.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars425.png: 320x640 1 license_plate, 78.2ms
# Speed: 0.8ms preprocess, 78.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars419.png: 576x640 1 license_plate, 121.2ms
# Speed: 1.9ms preprocess, 121.2ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars418.png: 384x640 1 license_plate, 123.6ms
# Speed: 1.1ms preprocess, 123.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars342.png: 480x640 1 license_plate, 103.6ms
# Speed: 1.6ms preprocess, 103.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars424.png: 480x640 1 license_plate, 105.5ms
# Speed: 1.3ms preprocess, 105.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars430.png: 384x640 1 license_plate, 90.0ms
# Speed: 0.9ms preprocess, 90.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars356.png: 448x640 1 license_plate, 115.9ms
# Speed: 1.3ms preprocess, 115.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars381.png: 384x640 1 license_plate, 89.6ms
# Speed: 1.1ms preprocess, 89.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars395.png: 512x640 1 license_plate, 108.4ms
# Speed: 1.5ms preprocess, 108.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars168.png: 384x640 1 license_plate, 96.7ms
# Speed: 1.1ms preprocess, 96.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars140.png: 448x640 1 license_plate, 96.2ms
# Speed: 1.0ms preprocess, 96.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars154.png: 640x480 1 license_plate, 101.5ms
# Speed: 1.3ms preprocess, 101.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars89.png: 448x640 4 license_plates, 99.4ms
# Speed: 1.1ms preprocess, 99.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars62.png: 480x640 1 license_plate, 103.2ms
# Speed: 1.3ms preprocess, 103.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars76.png: 480x640 2 license_plates, 100.0ms
# Speed: 1.2ms preprocess, 100.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars183.png: 384x640 1 license_plate, 91.4ms
# Speed: 1.0ms preprocess, 91.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars197.png: 384x640 1 license_plate, 89.4ms
# Speed: 1.1ms preprocess, 89.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars236.png: 288x640 2 license_plates, 123.5ms
# Speed: 0.8ms preprocess, 123.5ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /Users/aidanmacnichol/Documents/uofc/ENEL645/ENEL645_Project_Group2/segment/car-license-plate-detection/images/Cars222.png: 384x640 1 license_plate, 88.1ms
# Speed: 0.9ms preprocess, 88.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
